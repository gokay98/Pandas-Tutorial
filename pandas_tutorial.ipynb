# %%
import pandas as pd

# %%
data = pd.read_csv('titanic.csv')

# %%
data.head()
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1
# 4         1        0

# %%
data.tail(2)
# Out:
#                   Name PClass   Age   Sex  Survived  SexCode
# 1311  Lievens, Mr Rene    3rd  24.0  male         0        0
# 1312    Zimmerman, Leo    3rd  29.0  male         0        0

# %%
data.shape
# Out:
# (1313, 6)

# %% [markdown]
# DATA iloc Kullanımı

# %%
data.iloc[0]
# Out:
# Name        Allen, Miss Elisabeth Walton
# PClass                               1st
# Age                                 29.0
# Sex                               female
# Survived                               1
# SexCode                                1
# Name: 0, dtype: object

# %%
data.iloc[0:3] #ilk 3 elemanı getirir
# Out:
#                                   Name PClass   Age     Sex  Survived  SexCode
# 0         Allen, Miss Elisabeth Walton    1st  29.0  female         1        1
# 1          Allison, Miss Helen Loraine    1st   2.0  female         0        1
# 2  Allison, Mr Hudson Joshua Creighton    1st  30.0    male         0        0

# %%
#iloc fonksiynunda ilk row sonra column gelir
#data.iloc(row,column)
#eğer ki 0 dan 3. rowun sadece iki column unu almak istersem virgül ile ayrımam gerekir.

data.iloc[0:3 ,0:2] #ilk 3 rowun ilk iki columnunu getirir
# Out:
#                                   Name PClass
# 0         Allen, Miss Elisabeth Walton    1st
# 1          Allison, Miss Helen Loraine    1st
# 2  Allison, Mr Hudson Joshua Creighton    1st

# %%
data.iloc[-3: ,0:2] ##son 3 rowun ilk iki columnunu getirir
# Out:
#                   Name PClass
# 1310  Zenni, Mr Philip    3rd
# 1311  Lievens, Mr Rene    3rd
# 1312    Zimmerman, Leo    3rd

# %%
data.iloc[3:6 ,:] # 0 yazmaya gerek yok : işaretini kullanarak tüm columnları alabilirim
# 0: dan sonra eğer yine sayı yazmazsam son elemana kadar alır data.iloc[3:6 ,1:]
# Out:
#                                             Name PClass    Age     Sex  \
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
# 5                             Anderson, Mr Harry    1st  47.00    male
#
#    Survived  SexCode
# 3         0        1
# 4         1        0
# 5         1        0

# %% [markdown]
# Veri Maskeleme / Filitreleme

# %%
#sadece female olan dataları almak için:

data['Sex']
# Out:
# 0       female
# 1       female
# 2         male
# 3       female
# 4         male
#          ...
# 1308      male
# 1309      male
# 1310      male
# 1311      male
# 1312      male
# Name: Sex, Length: 1313, dtype: object

# %%
data["Sex"]  == "female"  # sadece cinsiyeti female olanları True yapar
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 1308    False
# 1309    False
# 1310    False
# 1311    False
# 1312    False
# Name: Sex, Length: 1313, dtype: bool

# %%
data[ data["Sex"]  == "female"]  # veriden cinsiyeti female olanları alır
# Out:
#                                                Name PClass   Age     Sex  \
# 0                      Allen, Miss Elisabeth Walton    1st  29.0  female
# 1                       Allison, Miss Helen Loraine    1st   2.0  female
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
# 6                  Andrews, Miss Kornelia Theodosia    1st  63.0  female
# 8      Appleton, Mrs Edward Dale (Charlotte Lamson)    1st  58.0  female
# ...                                             ...    ...   ...     ...
# 1283            Vestrom, Miss Hulda Amanda Adolfina    3rd  14.0  female
# 1293                              Wilkes, Mrs Ellen    3rd  45.0  female
# 1304                            Yasbeck, Mrs Antoni    3rd  15.0  female
# 1306                            Zabour, Miss Hileni    3rd   NaN  female
# 1307                            Zabour, Miss Tamini    3rd   NaN  female
#
#       Survived  SexCode
# 0            1        1
# 1            0        1
# ...

# %% [markdown]
# DATA DEĞİŞTİRME

# %%
data["Sex"] = data["Sex"].replace(['female',"male"],["F","M"])  # cinsiyetleri F ve M olarak değiştirir

# %%
data
# Out:
#                                                Name PClass    Age Sex  \
# 0                      Allen, Miss Elisabeth Walton    1st  29.00   F
# 1                       Allison, Miss Helen Loraine    1st   2.00   F
# 2               Allison, Mr Hudson Joshua Creighton    1st  30.00   M
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00   F
# 4                     Allison, Master Hudson Trevor    1st   0.92   M
# ...                                             ...    ...    ...  ..
# 1308                             Zakarian, Mr Artun    3rd  27.00   M
# 1309                         Zakarian, Mr Maprieder    3rd  26.00   M
# 1310                               Zenni, Mr Philip    3rd  22.00   M
# 1311                               Lievens, Mr Rene    3rd  24.00   M
# 1312                                 Zimmerman, Leo    3rd  29.00   M
#
#       Survived  SexCode
# 0            1        1
# 1            0        1
# 2            0        0
# 3            0        1
# ...

# %% [markdown]
# DATAFRAME BAŞLIK DEĞİŞTİRME

# %%
data.rename(columns={"PClass" : "Passenger Class", "Sex" : " Gender"}, inplace = True)  # PClass columnunu Passenger Class olarak değiştirir,

# %%
data
# Out:
#                                                Name Passenger Class    Age  \
# 0                      Allen, Miss Elisabeth Walton             1st  29.00
# 1                       Allison, Miss Helen Loraine             1st   2.00
# 2               Allison, Mr Hudson Joshua Creighton             1st  30.00
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)             1st  25.00
# 4                     Allison, Master Hudson Trevor             1st   0.92
# ...                                             ...             ...    ...
# 1308                             Zakarian, Mr Artun             3rd  27.00
# 1309                         Zakarian, Mr Maprieder             3rd  26.00
# 1310                               Zenni, Mr Philip             3rd  22.00
# 1311                               Lievens, Mr Rene             3rd  24.00
# 1312                                 Zimmerman, Leo             3rd  29.00
#
#       Gender  Survived  SexCode
# 0          F         1        1
# ...

# %% [markdown]
# Data İstatislikleri

# %%
data["Age"].max
# Out:
# <bound method Series.max of 0       29.00
# 1        2.00
# 2       30.00
# 3       25.00
# 4        0.92
#         ...
# 1308    27.00
# 1309    26.00
# 1310    22.00
# 1311    24.00
# 1312    29.00
# Name: Age, Length: 1313, dtype: float64>

# %%
data['Age'].count()
# Out:
# np.int64(756)

# %%
data
# Out:
#                                                Name Passenger Class    Age  \
# 0                      Allen, Miss Elisabeth Walton             1st  29.00
# 1                       Allison, Miss Helen Loraine             1st   2.00
# 2               Allison, Mr Hudson Joshua Creighton             1st  30.00
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)             1st  25.00
# 4                     Allison, Master Hudson Trevor             1st   0.92
# ...                                             ...             ...    ...
# 1308                             Zakarian, Mr Artun             3rd  27.00
# 1309                         Zakarian, Mr Maprieder             3rd  26.00
# 1310                               Zenni, Mr Philip             3rd  22.00
# 1311                               Lievens, Mr Rene             3rd  24.00
# 1312                                 Zimmerman, Leo             3rd  29.00
#
#       Gender  Survived  SexCode
# 0          F         1        1
# ...

# %%
data['Passenger Class'].unique()  #  cinsiyetlerin benzersiz değerlerini getirir
# Out:
# array(['1st', '2nd', '*', '3rd'], dtype=object)

# %%
data['Passenger Class'].value_counts()  #  cinsiyetlerin benzersiz değerlerini getirir
# Out:
# Passenger Class
# 3rd    711
# 1st    322
# 2nd    279
# *        1
# Name: count, dtype: int64

# %%
data.isnull().sum()  #  hangi veriden ne kadar eksik var onları görürüm
# Out:
# Name                 0
# Passenger Class      0
# Age                557
#  Gender              0
# Survived             0
# SexCode              0
# dtype: int64

# %%
data.groupby(by=["Sex"]).count()  #  cinsiyete göre yaşların ortalamasını alır
# Out:
#         Name  PClass  Age  Survived  SexCode
# Sex
# female   462     462  288       462      462
# male     851     851  468       851      851

# %%
data.groupby(by=["Sex"]).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\gokay\Desktop\ai\pandas_lib_tutorial\venv\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\gokay\Desktop\ai\pandas_lib_tutorial\venv\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\gokay\Desktop\ai\pandas_lib_tutorial\venv\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
# ...

# %% [markdown]
# Column Silme

# %%
data.drop(labels = "Sex", axis = 1, inplace = True)  #axis = 1 columnları siler axis = 0 ise rowları siler
data
# Out:
#                                                Name PClass    Age  Survived  \
# 0                      Allen, Miss Elisabeth Walton    1st  29.00         1
# 1                       Allison, Miss Helen Loraine    1st   2.00         0
# 2               Allison, Mr Hudson Joshua Creighton    1st  30.00         0
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00         0
# 4                     Allison, Master Hudson Trevor    1st   0.92         1
# ...                                             ...    ...    ...       ...
# 1308                             Zakarian, Mr Artun    3rd  27.00         0
# 1309                         Zakarian, Mr Maprieder    3rd  26.00         0
# 1310                               Zenni, Mr Philip    3rd  22.00         0
# 1311                               Lievens, Mr Rene    3rd  24.00         0
# 1312                                 Zimmerman, Leo    3rd  29.00         0
#
#       SexCode
# 0           1
# 1           1
# ...

# %%
data.drop(data[data["Sex"] == "female"].index, inplace = True) # female cinsiyetine sahip herkesi siler
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\gokay\Desktop\ai\pandas_lib_tutorial\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sex'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ...

# %% [markdown]
# DÖNGÜLER

# %%
for name in data["Name"][0:10]:
    print(name)  # ilk 10 rowu yazdırır
# Out:
# Allen, Miss Elisabeth Walton
# Allison, Miss Helen Loraine
# Allison, Mr Hudson Joshua Creighton
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)
# Allison, Master Hudson Trevor
# Anderson, Mr Harry
# Andrews, Miss Kornelia Theodosia
# Andrews, Mr Thomas, jr
# Appleton, Mrs Edward Dale (Charlotte Lamson)
# Artagaveytia, Mr Ramon
